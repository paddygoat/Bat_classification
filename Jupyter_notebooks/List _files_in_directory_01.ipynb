# %%
import os

dir_to_read_01 = dict()
dir_to_read_02 = dict()
dir_to_read_03 = dict()
dir_to_read_04 = dict()
dir_to_read_05 = dict()
dir_to_read_06 = dict()
dir_to_read_07 = dict()
dir_to_read_08 = dict()
dir_to_read_09 = dict()
dir_to_read_10 = dict()
dir_to_read_11 = dict()
dir_to_read_12 = dict()
dir_to_read_13 = dict()
dir_to_read_14 = dict()
dir_to_read_15 = dict()
dir_to_read_16 = dict()
dir_to_read_17 = dict()
dir_to_read_18 = dict()
dir_to_read_19 = dict()
dir_to_read_20 = dict()
dir_to_read_21 = dict()
dir_to_read_22 = dict()
text = dict()
file_list = dict()

file_to_write = dict()

dir_to_read_01 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Barbastella_barbastellus_a"
dir_to_read_02 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Barbastella_barbastellus_b"
dir_to_read_03 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Eptesicus_nilssonii_a"
dir_to_read_04 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Eptesicus_serotinus_a"
dir_to_read_05 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Miniopterus_schreibersii_a"
dir_to_read_06 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Miniopterus_schreibersii_b"
dir_to_read_07 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Myotis_bechsteinii_a"
dir_to_read_08 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Myotis_bechsteinii_b"
dir_to_read_09 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Myotis_bechsteinii_c"
dir_to_read_10 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Myotis_bechsteinii_d"
dir_to_read_11 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Nyctalus_noctula_a"
dir_to_read_12 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Nyctalus_noctula_b"
dir_to_read_13 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Nyctalus_noctula_c"
dir_to_read_14 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Nyctalus_noctula_d"
dir_to_read_15 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Nyctalus_noctula_e"
dir_to_read_16 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Pipistrellus_pipistrellus_a"
dir_to_read_17 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Pipistrellus_pipistrellus_b"
dir_to_read_18 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Pipistrellus_pipistrellus_c"
dir_to_read_19 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/Plecotus_auritus_a"
dir_to_read_20 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/bird"
dir_to_read_21 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/cat"
dir_to_read_22 = "/media/tegwyn/Xavier_SD/Bat_Detecter/Bat_data_01/dog"


file_to_write = '/media/tegwyn/Xavier_SD/TensorFlow_speech_backups/speech_dataset/speech_commands_v0.02/my_file.txt'

file_list = os.listdir(dir_to_read_01)
file_list = file_list + os.listdir(dir_to_read_02)
file_list = file_list + os.listdir(dir_to_read_03)
file_list = file_list + os.listdir(dir_to_read_04)
file_list = file_list + os.listdir(dir_to_read_05)
file_list = file_list + os.listdir(dir_to_read_06)
file_list = file_list + os.listdir(dir_to_read_07)
file_list = file_list + os.listdir(dir_to_read_08)
file_list = file_list + os.listdir(dir_to_read_09)
file_list = file_list + os.listdir(dir_to_read_10)
file_list = file_list + os.listdir(dir_to_read_11)
file_list = file_list + os.listdir(dir_to_read_12)
file_list = file_list + os.listdir(dir_to_read_13)
file_list = file_list + os.listdir(dir_to_read_14)
file_list = file_list + os.listdir(dir_to_read_15)
file_list = file_list + os.listdir(dir_to_read_16)
file_list = file_list + os.listdir(dir_to_read_17)
file_list = file_list + os.listdir(dir_to_read_18)
file_list = file_list + os.listdir(dir_to_read_19)
file_list = file_list + os.listdir(dir_to_read_20)
file_list = file_list + os.listdir(dir_to_read_21)
file_list = file_list + os.listdir(dir_to_read_22)


with open(file_to_write, 'w') as f:

    a = file_list
    print('\n'.join(map(str, a)))
    b = ('\n'.join(map(str, a)))
    f.write("%s\n" % b)
# Out:
# Barbastella_barbastellus_a_01.wav
# Barbastella_barbastellus_b_08.wav
# Barbastella_barbastellus_b_14.wav
# Barbastella_barbastellus_b_12.wav
# Barbastella_barbastellus_b_03.wav
# Barbastella_barbastellus_b_15.wav
# Barbastella_barbastellus_b_11.wav
# Barbastella_barbastellus_b_07.wav
# Barbastella_barbastellus_b_09.wav
# Barbastella_barbastellus_b_17.wav
# Barbastella_barbastellus_b_10.wav
# Barbastella_barbastellus_b_16.wav
# Barbastella_barbastellus_b_01.wav
# Barbastella_barbastellus_b_05.wav
# Barbastella_barbastellus_b_04.wav
# Barbastella_barbastellus_b_13.wav
# Barbastella_barbastellus_b_06.wav
# Barbastella_barbastellus_b_02.wav
# Eptesicus_nilssonii_a_33.wav
# Eptesicus_nilssonii_a_02.wav
# Eptesicus_nilssonii_a_32.wav
# Eptesicus_nilssonii_a_24.wav
# Eptesicus_nilssonii_a_29.wav
# Eptesicus_nilssonii_a_01.wav
# Eptesicus_nilssonii_a_31.wav
# Eptesicus_nilssonii_a_04.wav
# Eptesicus_nilssonii_a_14.wav
# Eptesicus_nilssonii_a_09.wav
# Eptesicus_nilssonii_a_07.wav
# ...
